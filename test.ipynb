# %%
# %timeit x = 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = x
#
# NameError: name 'x' is not defined

# %%
print("Hallo Welt")
# Out:
# Hallo Welt

# %%
print(x)
# Out:
# 10
