# %% [markdown]
# # Working directory magic with generated CSV

# %%
import pandas as pd

df = pd.DataFrame({"name": ["Ada", "Grace"], "score": [95, 98]})
df.to_csv("scores.csv", index=False)

# %%
# %cd .

# %%
loaded = pd.read_csv("scores.csv")
print(loaded)
